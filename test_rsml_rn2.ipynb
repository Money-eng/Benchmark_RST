# %%
import openalea.rsml

# %%
mtg = openalea.rsml.rsml2mtg("/home/loai/Documents/code/RSMLExtraction/temp/rn2_test/CE/HG_roots_epoch_13400/230629PN031_t_0027.rsml")

# %%
import matplotlib.pyplot as plt
import openalea.rsml.plot as rsml_plot
rsml_plot.plot2d(mtg)
plt.show()
