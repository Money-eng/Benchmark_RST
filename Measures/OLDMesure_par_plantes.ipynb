# %%
from pathlib import Path

import pandas as pd

# %%
# --- par‑box ---------------------------------------------------------------
path_box = Path("/home/loai/Documents/code/RSMLExtraction/Results/Measures/results_per_box.csv")
df_box_wid = pd.read_csv(path_box)

# Le nouveau fichier a 3 colonnes de mesures qu’on convertit en format long :
df_box = df_box_wid.melt(
    id_vars=["model", "split", "box", "metric", "time"],
    value_vars=["Prediction", "expertized", "before_expertized"],
)

# --- par‑plant -------------------------------------------------------------
path_plant = Path("/home/loai/Documents/code/RSMLExtraction/Results/Measures/results_per_plant.csv")
df_plant = pd.read_csv(path_plant)  # est déjà au format long (colonne « source »)

# %%
df_box
# Out:
#                     model split          box                metric  time  \
# 0      Segformer_bce_dice   Val  230629PN006        NumberOfPlants     1
# 1      Segformer_bce_dice   Val  230629PN006        NumberOfOrgans     1
# 2      Segformer_bce_dice   Val  230629PN006       TotalRootLength     1
# 3      Segformer_bce_dice   Val  230629PN006  NumberOfLateralRoots     1
# 4      Segformer_bce_dice   Val  230629PN006        NumberOfPlants     2
# ...                   ...   ...          ...                   ...   ...
# 20875       Unet_bce_dice  Test  230629PN024  NumberOfLateralRoots    28
# 20876       Unet_bce_dice  Test  230629PN024        NumberOfPlants    29
# 20877       Unet_bce_dice  Test  230629PN024        NumberOfOrgans    29
# 20878       Unet_bce_dice  Test  230629PN024       TotalRootLength    29
# 20879       Unet_bce_dice  Test  230629PN024  NumberOfLateralRoots    29
#
#                 variable        value
# 0             Prediction     5.000000
# 1             Prediction     5.000000
# 2             Prediction   937.896972
# 3             Prediction     0.000000
# 4             Prediction     5.000000
# ...                  ...          ...
# 20875  before_expertized    70.000000
# 20876  before_expertized     5.000000
# 20877  before_expertized    75.000000
# 20878  before_expertized  9552.798533
# 20879  before_expertized    70.000000
#
# [20880 rows x 7 columns]
